# %% [markdown]
# # Exercício

# %% [markdown]
# Utilizar o dataset `Life Expectancy` do [Kaggle](https://www.kaggle.com/kumarajarshi/life-expectancy-who) da World Health Organization.
# O objetivo é realizar a predição da expectativa de vida, utilizando as variáveis disponíveis no Dataset.

# %% [markdown]
# ### Obtendo os dados
#
# Os dados podem ser obtidos na [página da competição](https://www.kaggle.com/kumarajarshi/life-expectancy-who), ou do link do dropbox com o comando abaixo:

# %%
# !wget -c https://www.dropbox.com/s/y6e7kky6rpr25jv/Life%20Expectancy%20Data.csv?dl=0 -O life_expectancy.csv
# Out:
# --2021-03-11 21:17:32--  https://www.dropbox.com/s/y6e7kky6rpr25jv/Life%20Expectancy%20Data.csv?dl=0
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.82.18, 2620:100:6032:18::a27d:5212
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.82.18|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /s/raw/y6e7kky6rpr25jv/Life%20Expectancy%20Data.csv [following]
# --2021-03-11 21:17:32--  https://www.dropbox.com/s/raw/y6e7kky6rpr25jv/Life%20Expectancy%20Data.csv
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uc89252029d529b53c6696f6c650.dl.dropboxusercontent.com/cd/0/inline/BKhcBO_mdcDMPy8Cne2s466P2suN9lFajIl3Cg5nxowumQHn3dNqMZtLi4a7Tuj5mQX7eTNHS2aLyCAVZxGdQW-uc9Er2W5Luy2tLdXInTiuT9Q07CEE_9A7vvGLKPsIHvcKY2pKo9JQaXirk0hMwR-s/file# [following]
# ...

# %%
# !head -10 life_expectancy.csv
# Out:
# Country,Year,Status,Life expectancy ,Adult Mortality,infant deaths,Alcohol,percentage expenditure,Hepatitis B,Measles , BMI ,under-five deaths ,Polio,Total expenditure,Diphtheria , HIV/AIDS,GDP,Population, thinness  1-19 years, thinness 5-9 years,Income composition of resources,Schooling
# Afghanistan,2015,Developing,65,263,62,0.01,71.27962362,65,1154,19.1,83,6,8.16,65,0.1,584.25921,33736494,17.2,17.3,0.479,10.1
# Afghanistan,2014,Developing,59.9,271,64,0.01,73.52358168,62,492,18.6,86,58,8.18,62,0.1,612.696514,327582,17.5,17.5,0.476,10
# Afghanistan,2013,Developing,59.9,268,66,0.01,73.21924272,64,430,18.1,89,62,8.13,64,0.1,631.744976,31731688,17.7,17.7,0.47,9.9
# Afghanistan,2012,Developing,59.5,272,69,0.01,78.1842153,67,2787,17.6,93,67,8.52,67,0.1,669.959,3696958,17.9,18,0.463,9.8
# Afghanistan,2011,Developing,59.2,275,71,0.01,7.097108703,68,3013,17.2,97,68,7.87,68,0.1,63.537231,2978599,18.2,18.2,0.454,9.5
# ...

# %% [markdown]
# ### Atividades
#
# 1. Criar Máquina virtual utilizando o serviço EC2 da Amazon AWS - utilizar Ubuntu como Sistema Operacional;
# 1. Instalar o gerenciador de ambientes Miniconda, utilizando o [link](https://repo.anaconda.com/miniconda/Miniconda3-latest-Linux-x86_64.sh).
# 1. Instalar dependências necessárias para a Regressão;
# 1. Fazer a Instalação do `Jupyter Lab` utilizando a ferramenta `conda`;
# 1. Fazer o upload deste notebook para o servidor Jupyter recém instalado;
# 1. Alterar Notebook na Seção "Solução" com passo a passo em Python ou R para realizar a predição da Expectativa de Vida;
# 1. Realizar o upload do notebook contendo a solução no blackboard.

# %% [markdown]
# ## Solução
# O passo a passo da sua solução deve vir abaixo dessa Seção.

# %%
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('life_expectancy.csv')
df
# Out:
#           Country  Year  ... Income composition of resources  Schooling
# 0     Afghanistan  2015  ...                           0.479       10.1
# 1     Afghanistan  2014  ...                           0.476       10.0
# 2     Afghanistan  2013  ...                           0.470        9.9
# 3     Afghanistan  2012  ...                           0.463        9.8
# 4     Afghanistan  2011  ...                           0.454        9.5
# ...           ...   ...  ...                             ...        ...
# 2933     Zimbabwe  2004  ...                           0.407        9.2
# 2934     Zimbabwe  2003  ...                           0.418        9.5
# 2935     Zimbabwe  2002  ...                           0.427       10.0
# 2936     Zimbabwe  2001  ...                           0.427        9.8
# 2937     Zimbabwe  2000  ...                           0.434        9.8
#
# [2938 rows x 22 columns]

# %%
plt.scatter(x=df.iloc[:,3], y=df.iloc[:,11])
plt.xlabel("Life Expectancy")
plt.ylabel("BMI")
# Out:
# Text(0, 0.5, 'BMI')

# %%
plt.scatter(x=df.iloc[:,3], y=df.iloc[:,15])
plt.xlabel("Life Expectancy")
plt.ylabel("HIV")

# %%
plt.figure(figsize=(15,10))
sns.heatmap(df.corr(),annot=True)

# %%
df.columns
# Out:
# Index(['Country', 'Year', 'Status', 'Life expectancy ', 'Adult Mortality',
#        'infant deaths', 'Alcohol', 'percentage expenditure', 'Hepatitis B',
#        'Measles ', ' BMI ', 'under-five deaths ', 'Polio', 'Total expenditure',
#        'Diphtheria ', ' HIV/AIDS', 'GDP', 'Population',
#        ' thinness  1-19 years', ' thinness 5-9 years',
#        'Income composition of resources', 'Schooling'],
#       dtype='object')

# %%
plt.figure(figsize=(12,8))
_ = plt.plot(df['Life expectancy '],df['Income composition of resources'], marker='.', linewidth=0, color='blue')
_ = plt.grid(which='major', color='#cccccc', alpha=0.45)
_ = plt.title('Life expectancy vc Income composition of resources ', family='Arial', fontsize=12)
_ = plt.xlabel('Life expectancy')
_ = plt.ylabel('Income composition of resources')
_ = plt.show()
# Out:
# findfont: Font family ['Arial'] not found. Falling back to DejaVu Sans.

# %%
sns.scatterplot(x='Life expectancy ',y='Diphtheria ', data=df)
plt.figure(figsize=(15,10))
plt.show()

# %%
plt.figure(figsize=(12,8))
_ = plt.plot(df['Life expectancy '],df['GDP'], marker='.', linewidth=0, color='blue')
_ = plt.grid(which='major', color='#cccccc', alpha=0.45)
_ = plt.title('Life expectancy vc GDP ', family='Arial', fontsize=12)
_ = plt.xlabel('Life expectancy')
_ = plt.ylabel('GDP')
_ = plt.show()

# %%
df[df['Country']=='Brazil'].groupby(['Country','Year'])['Adult Mortality','infant deaths'].mean()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.
#               Adult Mortality  infant deaths
# Country Year
# Brazil  2000            183.0            111
#         2001            179.0            103
#         2002            176.0             95
#         2003            172.0             88
#         2004             17.0             81
#         2005            163.0             75
#         2006            161.0             70
#         2007            159.0             65
#         2008            158.0             61
#         2009            157.0             57
#         2010            154.0             54
#         2011            152.0             51
#         2012            148.0             49
#         2013            146.0             46
# ...

# %% [markdown]
# Regressão Linear

# %%
for label, content in df.items():
  if pd.isnull(content).sum():
    df[label] = content.fillna(0)

# %%
y = df['Life expectancy ']
#y = y.fillna(0,inplace=True)
X = df.copy()
X.drop(['Life expectancy ','Country','Status'],axis=1, inplace=True)
#X.fillna(0,inplace=True)
X
# Out:
#       Year  Adult Mortality  ...  Income composition of resources  Schooling
# 0     2015            263.0  ...                            0.479       10.1
# 1     2014            271.0  ...                            0.476       10.0
# 2     2013            268.0  ...                            0.470        9.9
# 3     2012            272.0  ...                            0.463        9.8
# 4     2011            275.0  ...                            0.454        9.5
# ...    ...              ...  ...                              ...        ...
# 2933  2004            723.0  ...                            0.407        9.2
# 2934  2003            715.0  ...                            0.418        9.5
# 2935  2002             73.0  ...                            0.427       10.0
# 2936  2001            686.0  ...                            0.427        9.8
# 2937  2000            665.0  ...                            0.434        9.8
#
# [2938 rows x 19 columns]

# %%
X.isnull().any()
# Out:
# Year                               False
# Adult Mortality                    False
# infant deaths                      False
# Alcohol                            False
# percentage expenditure             False
# Hepatitis B                        False
# Measles                            False
#  BMI                               False
# under-five deaths                  False
# Polio                              False
# Total expenditure                  False
# Diphtheria                         False
#  HIV/AIDS                          False
# GDP                                False
# Population                         False
#  thinness  1-19 years              False
#  thinness 5-9 years                False
# Income composition of resources    False
# Schooling                          False
# dtype: bool

# %%
import numpy as np

np.isnan(X.any()) #and gets False
# Out:
# Year                               False
# Adult Mortality                    False
# infant deaths                      False
# Alcohol                            False
# percentage expenditure             False
# Hepatitis B                        False
# Measles                            False
#  BMI                               False
# under-five deaths                  False
# Polio                              False
# Total expenditure                  False
# Diphtheria                         False
#  HIV/AIDS                          False
# GDP                                False
# Population                         False
#  thinness  1-19 years              False
#  thinness 5-9 years                False
# Income composition of resources    False
# Schooling                          False
# dtype: bool

# %%
#X = X.values.astype(np.float64)
#y = y.values.astype(np.float64)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test= train_test_split(X,y,test_size=0.3,random_state=22)

# %%
from sklearn.linear_model import LinearRegression
# Fit the model
lm = LinearRegression()
lm.fit(X_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
lm.coef_
# Out:
# array([ 3.23232025e-02, -1.95696163e-02,  1.24737087e-01,  3.64588844e-01,
#         1.69904583e-05, -1.70276872e-03, -9.85435281e-06,  5.90132792e-02,
#        -9.39820383e-02,  3.59382483e-02, -7.98595527e-02,  3.06229949e-02,
#        -5.06399617e-01,  7.22552278e-05,  7.49948067e-10, -7.46779510e-02,
#        -4.25245270e-02,  3.74483383e+00,  2.79510363e-01])

# %%
prediction = lm.predict(X_test)

# %%
sns.distplot((y_test-prediction),bins=30)
plt.title('Treino vs Predicao')
sns.set()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# #Avaliando a perfomance do modelo
#
#
# Mean Absolute Error (MAE) : é a média do valor absoluto dos erros.
#
# Mean Squared Error (MSE) : é a média do erro dos quadrados
#
# Root Mean Squared Error (RMSE) Raiz quadrada do erro dos quadrados

# %%
from sklearn import metrics

print('MAE:', metrics.mean_absolute_error(y_test, prediction))
print('MSE:', metrics.mean_squared_error(y_test, prediction))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, prediction)))
print('R2:', lm.score(X_train,y_train))
# Out:
# MAE: 3.733506128918336
# MSE: 48.16487246336371
# RMSE: 6.940091675429346
# R2: 0.6957137066633126
